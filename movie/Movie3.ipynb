# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('movie_metadata.csv')

# %% [markdown]
# # Original Missing values

# %%
import missingno
missingno.matrix(dataset)

# %%
dataset.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# # Removing unwanted columns

# %%
lis=['color','actor_1_name','director_name','movie_title','language','country','actor_2_name','actor_3_name','cast_total_facebook_likes','movie_imdb_link']
dataset.drop(lis,inplace=True,axis=1)

# %% [markdown]
# # To check missing values after every steps

# %%
missingno.matrix(dataset)

# %% [markdown]
# # Replaced criric reviews null value with most frequent

# %%
print(dataset['num_critic_for_reviews'].median())
print(dataset['num_critic_for_reviews'].mean())
print(dataset['num_critic_for_reviews'].value_counts().index[0])
# Out:
# 110.0
# 140.1942719807731
# 1.0

# %%
dataset['num_critic_for_reviews'].fillna(dataset['num_critic_for_reviews'].value_counts().index[0],inplace=True)
plt.scatter(dataset['num_critic_for_reviews'],dataset['imdb_score'])

# %% [markdown]
# # graph shows imdb depends on critic reviews

# %%
plt.scatter(dataset['duration'],dataset['imdb_score'])

# %% [markdown]
# # Deleting extra ordinary row shown in above plot with duration of almost 500

# %%
dataset.drop(dataset[dataset.duration>400].index, inplace=True)
plt.scatter(dataset['duration'],dataset['imdb_score'])

# %% [markdown]
# # Replace missing value with mean

# %%
print(dataset['duration'].median())
print(dataset['duration'].mean())
print(dataset['duration'].value_counts().index[0])
# Out:
# 103.0
# 107.12074796101054
# 90.0

# %%
dataset['duration'].fillna(dataset['duration'].value_counts().index[0],inplace=True)

# %%
plt.scatter(dataset['facenumber_in_poster'],dataset['imdb_score'])

# %% [markdown]
# # Removing 2 noisy data  in above plot with value >30

# %%
dataset.drop(dataset[dataset.facenumber_in_poster>20].index, inplace=True)

# %% [markdown]
# # Replacing missing values with mode value

# %%
print(dataset['facenumber_in_poster'].median())
print(dataset['facenumber_in_poster'].mean())
print(dataset['facenumber_in_poster'].value_counts().index[0])#mode
# Out:
# 1.0
# 1.3572707380147204
# 0.0

# %%
dataset['facenumber_in_poster'].fillna(dataset['facenumber_in_poster'].value_counts().index[0],inplace=True)

# %%
plt.scatter(dataset['facenumber_in_poster'],dataset['imdb_score'])

# %%
dataset['num_user_for_reviews'].fillna(dataset['num_user_for_reviews'].value_counts().index[0],inplace=True)

# %%
plt.scatter(dataset['gross'],dataset['imdb_score'])

# %% [markdown]
# # As there are many null values in column ,so I dropped this gross column

# %%
dataset.drop(['gross'],inplace=True,axis=1)

# %%
plt.scatter(dataset['budget'],dataset['imdb_score'])

# %% [markdown]
# # Replace missing budget with mode value

# %%
dataset['budget'].fillna(dataset['budget'].value_counts().index[0],inplace=True)

# %% [markdown]
# # Replacing missing rating with 'Not Rated' rating

# %%
dataset['content_rating'].fillna('Not Rated',inplace=True)

# %% [markdown]
# # Deleting unwanted columns

# %%
dataset.drop(['genres'],inplace=True,axis=1)
dataset.drop(['title_year'],inplace=True,axis=1)
dataset.drop(['plot_keywords'],inplace=True,axis=1)
dataset.drop(['aspect_ratio'],inplace=True,axis=1)#many null values
plt.scatter(dataset['actor_1_facebook_likes'],dataset['imdb_score'])

# %%
plt.scatter(dataset['director_facebook_likes'],dataset['imdb_score'])

# %%
plt.scatter(dataset['actor_2_facebook_likes'],dataset['imdb_score'])

# %%
plt.scatter(dataset['actor_3_facebook_likes'],dataset['imdb_score'])

# %% [markdown]
# # Replace missing likes with most frequent value

# %%
dataset['actor_1_facebook_likes'].fillna(dataset['actor_1_facebook_likes'].value_counts().index[0],inplace=True)
dataset['director_facebook_likes'].fillna(dataset['director_facebook_likes'].value_counts().index[0],inplace=True)
dataset['actor_2_facebook_likes'].fillna(dataset['actor_2_facebook_likes'].value_counts().index[0],inplace=True)
dataset['actor_3_facebook_likes'].fillna(dataset['actor_3_facebook_likes'].value_counts().index[0],inplace=True)

# %% [markdown]
# # One hot Encoding on Content rating by get dummies

# %%
dataset = pd.concat([dataset,pd.get_dummies(dataset['content_rating'], prefix='cr')],axis=1)

# %%
dataset.drop(['content_rating'],inplace=True,axis=1)

# %% [markdown]
# # Categorize  imdb score (0-4,4-6,6-8 and 8-10) to avoid 'type: continous' error while training

# %%
dataset['imdb_binned_score']=pd.cut(dataset['imdb_score'], bins=[0,4,6,8,10], right=True, labels=False)+1

# %%
dataset.imdb_binned_score.value_counts()
# Out:
# 3    3203
# 2    1411
# 4     252
# 1     174
# Name: imdb_binned_score, dtype: int64

# %%
#dataset.drop('imdb_score',axis=1,inplace=True)

# %%
dataset.dtypes
# Out:
# num_critic_for_reviews     float64
# duration                   float64
# director_facebook_likes    float64
# actor_3_facebook_likes     float64
# actor_1_facebook_likes     float64
# num_voted_users              int64
# facenumber_in_poster       float64
# num_user_for_reviews       float64
# budget                     float64
# actor_2_facebook_likes     float64
# imdb_score                 float64
# movie_facebook_likes         int64
# cr_Approved                  uint8
# cr_G                         uint8
# cr_GP                        uint8
# cr_M                         uint8
# cr_NC-17                     uint8
# cr_Not Rated                 uint8
# cr_PG                        uint8
# cr_PG-13                     uint8
# cr_Passed                    uint8
# cr_R                         uint8
# cr_TV-14                     uint8
# cr_TV-G                      uint8
# cr_TV-MA                     uint8
# cr_TV-PG                     uint8
# cr_TV-Y                      uint8
# ...

# %% [markdown]
# # Train test split dataset and setting independent column as binned_imdb_score

# %%
from sklearn.model_selection import train_test_split

# %%
X=dataset.iloc[:,:-1].values

# %%
y=dataset.iloc[:,-1].values

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %% [markdown]
# # Featue Scaling dataset

# %%
from sklearn.preprocessing import StandardScaler
sc_X=StandardScaler()
X_train=sc_X.fit_transform(X_train)
X_test=sc_X.transform(X_test)

# %% [markdown]
# # Using k nearest neighbour to train model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=27)

# %%
knn.fit(X_train, np.ravel(y_train,order='C'))
# Out:
# KNeighborsClassifier(n_neighbors=27)

# %%
y_pred=knn.predict(X_test)

# %%
from sklearn import metrics

# %% [markdown]
# # Accuracy of model

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8888888888888888
