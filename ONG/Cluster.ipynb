# %%
import matplotlib.pyplot as plt
import numpy as np
np.set_printoptions(suppress=True)
import pandas as pd
from sklearn.cluster import KMeans
from scipy.spatial import distance_matrix
dataset = pd.read_csv("U1Test.csv")

# %%
dataset.head()
# Out:
#    Stg1 Pressure 1  Stg2 Pressure 2  Temp1-Temp2
# 0         35.31136          8.31016         16.9
# 1         34.31013          8.42420         24.8
# 2         28.40049          8.22458         28.1
# 3         29.42613          8.41537         31.4
# 4         30.37851          8.45384         32.7

# %%
dataset.drop('Temp1-Temp2',inplace=True,axis=1)
X=dataset.iloc[:,[0,1]].values
dataset.head()
# Out:
#    Stg1 Pressure 1  Stg2 Pressure 2
# 0         35.31136          8.31016
# 1         34.31013          8.42420
# 2         28.40049          8.22458
# 3         29.42613          8.41537
# 4         30.37851          8.45384

# %%
centroid_idx = [0,1,2] 
centroids = X[centroid_idx,:]
print(centroids)
# Out:
# [[35.31136  8.31016]
#  [34.31013  8.4242 ]
#  [28.40049  8.22458]]

# %%
kmeans = KMeans(n_clusters=3, init=centroids, max_iter=1,random_state=0)
y_kmeans=kmeans.fit_predict(X)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:969: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return_n_iter=True)

# %%
plt.figure(figsize=(25,5))
plt.scatter(X[y_kmeans==0,0],X[y_kmeans==0,1],s=100,c='red',label='Cluster_1')
plt.scatter(X[y_kmeans==1,0],X[y_kmeans==1,1],s=100,c='blue',label='Cluster_2')
plt.scatter(X[y_kmeans==2,0],X[y_kmeans==2,1],s=100,c='green',label='Cluster_3')
plt.scatter(centroids[:,0],centroids[:,1],s=300,c='yellow',label='centroid')
plt.show()
